# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import copy
from modules.Particle import Particle
from modules.Direct_Classes import Direct
from modules.FMM_Classes import FMM
from modules.BH_Classes import BH
import modules.Utility as util
from timeit import default_timer as timer
from scipy.optimize import curve_fit

ps = ([0] + list(range(1,34,3))) #finish at 34
thetas = [10,2,1.5,1.25,1,0.9,0.7,0.5,0.3]
ns = [2**n for n in range(2,14)] #finish at 14
box_size = 1000
max_property = 1

initial_2D_particle_collections = []
initial_3D_particle_collections = []
for n in ns:
    print("n:", n)
    initial_2D_particles = []
    initial_3D_particles = []
    initial_2D_positions = np.random.uniform(0,1,(n,2)) * box_size
    initial_3D_positions = np.random.uniform(0,1,(n,3)) * box_size
    for i, initial_2D_position in enumerate(initial_2D_positions):
        initial_2D_particles.append(Particle(initial_2D_position, np.random.uniform(0,max_property)))
        initial_3D_particles.append(Particle(initial_3D_positions[i], np.random.uniform(0,max_property)))
    initial_2D_particle_collections.append(initial_2D_particles)
    initial_3D_particle_collections.append(initial_3D_particles)

direct_2D_particles_collection = [copy.deepcopy(initial_2D_particle_collection) for initial_2D_particle_collection in initial_2D_particle_collections]
direct_2D_results = []
direct_3D_particles_collection = [copy.deepcopy(initial_3D_particle_collection) for initial_3D_particle_collection in initial_3D_particle_collections]
direct_3D_results = []

for i, direct_2D_particles in enumerate(direct_2D_particles_collection):
    print("i:", i)
    direct_2D_simulation = Direct(box_size, direct_2D_particles)
    direct_3D_simulation = Direct(box_size, direct_3D_particles_collection[i])
    timer_2D = timer()
    direct_2D_result = direct_2D_simulation.run_potential()
    direct_2D_result.sim_time = timer() - timer_2D
    timer_3D = timer()
    direct_3D_result = direct_3D_simulation.run_forces()
    direct_3D_result.sim_time = timer() - timer_3D
    direct_2D_results.append(direct_2D_result)
    direct_3D_results.append(direct_3D_result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# n: 4
# n: 8
# n: 16
# n: 32
# n: 64
# n: 128
# n: 256
# n: 512
# n: 1024
# n: 2048
# n: 4096
# n: 8192
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# 1000
# 1000
# i: 9
# 1000
# 2000
# 1000
# 2000
# i: 10
# 1000
# 2000
# 3000
# 4000
# 1000
# 2000
# 3000
# 4000
# i: 11
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000

# %%
#print(direct_2D_results[13].sim_time)
fmm_results = [[None for _ in range(len(ps))] for _ in range(len(ns))]
fmm_direct_diff_results = [[None for _ in range(len(ps))] for _ in range(len(ns))]
log_fmm_direct_diff_results = [[None for _ in range(len(ps))] for _ in range(len(ns))]

for i, n in enumerate(ns):
    for j, p in enumerate(ps):
        print(f"n: {n}, p: {p}")
        #print(f"i: {i}, j: {j}")
        fmm_particles = copy.deepcopy(initial_2D_particle_collections[i])
        # for particle in fmm_particles:
        #     print(particle.position, particle.property)
        # print(fmm_particles)
        fmm_simulation = FMM(box_size, fmm_particles, p=p)
        # print(fmm_simulation)
        # print(fmm_simulation.particles)
        # print(fmm_simulation.box_size)
        # print(fmm_simulation.p)
        fmm_timer = timer()
        fmm_result = fmm_simulation.run(False)
        sim_time = timer() - fmm_timer
        fmm_result.sim_time = sim_time

        fmm_direct_diff_result = util.calc_difference_results(fmm_particles, direct_2D_particles_collection[i], plotting=False)
        
        fmm_direct_diff_result.sim_time = sim_time
        log_fmm_direct_diff_result = util.calc_log_relative_error_results(fmm_particles, direct_2D_particles_collection[i], plotting=False)
        # print(log_fmm_direct_diff_result.max)
        log_fmm_direct_diff_result.sim_time = sim_time

        fmm_results[i][j] = fmm_result
        fmm_direct_diff_results[i][j] = fmm_direct_diff_result
        log_fmm_direct_diff_results[i][j] = log_fmm_direct_diff_result
# Out:
# n: 4, p: 0
# n: 4, p: 1
# n: 4, p: 4
# n: 4, p: 7
# n: 4, p: 10
# n: 4, p: 13
# n: 4, p: 16
# n: 4, p: 19
# n: 4, p: 22
# n: 4, p: 25
# n: 4, p: 28
# n: 4, p: 31
# n: 8, p: 0
# n: 8, p: 1
# n: 8, p: 4
# n: 8, p: 7
# n: 8, p: 10
# n: 8, p: 13
# n: 8, p: 16
# n: 8, p: 19
# /Users/thomashartigan/Documents/Uni/part II/Computing_Project/modules/Utility.py:51: RuntimeWarning: divide by zero encountered in log10
#   log_rel_errors = np.log10(np.abs(np.array(potential_differences) / np.array(reference_potentials)))
# n: 8, p: 22
# n: 8, p: 25
# n: 8, p: 28
# n: 8, p: 31
# n: 16, p: 0
# n: 16, p: 1
# n: 16, p: 4
# n: 16, p: 7
# n: 16, p: 10
# n: 16, p: 13
# n: 16, p: 16
# n: 16, p: 19
# n: 16, p: 22
# n: 16, p: 25
# n: 16, p: 28
# n: 16, p: 31
# n: 32, p: 0
# n: 32, p: 1
# n: 32, p: 4
# n: 32, p: 7
# n: 32, p: 10
# n: 32, p: 13
# n: 32, p: 16
# n: 32, p: 19
# n: 32, p: 22
# n: 32, p: 25
# n: 32, p: 28
# n: 32, p: 31
# n: 64, p: 0
# n: 64, p: 1
# n: 64, p: 4
# n: 64, p: 7
# n: 64, p: 10
# ...

# %%
#print(direct_2D_results[13].sim_time)
thetas = [10,2,1.5,1.25,1,0.9,0.7,0.5,0.3]
bh_results = [[None for _ in range(len(thetas))] for _ in range(len(ns))]
bh_direct_diff_results = [[None for _ in range(len(thetas))] for _ in range(len(ns))]
log_bh_direct_diff_results = [[None for _ in range(len(thetas))] for _ in range(len(ns))]
centre_position = np.ones(3) * box_size/2

for i, n in enumerate(ns):
    for j, theta in enumerate(thetas):
        print(f"n: {n}, theta: {theta}")
        #print(f"i: {i}, j: {j}")
        bh_particles = copy.deepcopy(initial_3D_particle_collections[i])
        # for particle in fmm_particles:
        #     print(particle.position, particle.property)
        # print(fmm_particles)
        bh_simulation = BH(box_size, bh_particles, theta=theta)
        # print(fmm_simulation)
        # print(fmm_simulation.particles)
        # print(fmm_simulation.box_size)
        # print(fmm_simulation.p)
        bh_timer = timer()
        bh_result = bh_simulation.run(centre_position, False)
        sim_time = timer() - bh_timer
        bh_result.sim_time = sim_time

        bh_direct_diff_result = util.calc_3D_difference_results(bh_particles, direct_3D_particles_collection[i], centre_position, plotting=False)
        
        bh_direct_diff_result.sim_time = sim_time
        log_bh_direct_diff_result = util.calc_3D_relative_error_results(bh_particles, direct_3D_particles_collection[i], centre_position, plotting=False)
        log_bh_direct_diff_result.sim_time = sim_time

        bh_results[i][j] = bh_result
        bh_direct_diff_results[i][j] = bh_direct_diff_result
        log_bh_direct_diff_results[i][j] = log_bh_direct_diff_result
# Out:
# n: 4, theta: 10
# n: 4, theta: 2
# n: 4, theta: 1.5
# n: 4, theta: 1.25
# n: 4, theta: 1
# n: 4, theta: 0.9
# n: 4, theta: 0.7
# n: 4, theta: 0.5
# n: 4, theta: 0.3
# n: 8, theta: 10
# n: 8, theta: 2
# n: 8, theta: 1.5
# n: 8, theta: 1.25
# n: 8, theta: 1
# n: 8, theta: 0.9
# n: 8, theta: 0.7
# n: 8, theta: 0.5
# n: 8, theta: 0.3
# n: 16, theta: 10
# n: 16, theta: 2
# n: 16, theta: 1.5
# n: 16, theta: 1.25
# n: 16, theta: 1
# n: 16, theta: 0.9
# n: 16, theta: 0.7
# n: 16, theta: 0.5
# n: 16, theta: 0.3
# n: 32, theta: 10
# n: 32, theta: 2
# n: 32, theta: 1.5
# /Users/thomashartigan/Documents/Uni/part II/Computing_Project/modules/Utility.py:85: RuntimeWarning: divide by zero encountered in log10
#   log_rel_errors = np.log10(np.abs(np.array(delta_accelerations) / np.array(reference_accelerations)))
# n: 32, theta: 1.25
# n: 32, theta: 1
# n: 32, theta: 0.9
# n: 32, theta: 0.7
# n: 32, theta: 0.5
# n: 32, theta: 0.3
# n: 64, theta: 10
# n: 64, theta: 2
# n: 64, theta: 1.5
# ...

# %%
final_fig, final_axs = plt.subplots(5, 2)
fmm_log2_n_p = []
fmm_log2_n_mean_log_accuracy = []
fmm_log2_n_max_log_accuracy = []
fmm_log_times = []
for i, n in enumerate(ns):
    for j, p in enumerate(ps):
        fmm_log2_n_p.append([np.log2(n),p])
        fmm_log2_n_mean_log_accuracy.append([np.log2(n), log_fmm_direct_diff_results[i][j].mean])
        fmm_log2_n_max_log_accuracy.append([np.log2(n), log_fmm_direct_diff_results[i][j].max])
        fmm_log_times.append(np.log10(log_fmm_direct_diff_results[i][j].sim_time))

fmm_log_n_p_result = util.analyse_2D([np.float64(item[0]) for item in fmm_log2_n_p], [np.float64(item[1]) for item in fmm_log2_n_p], np.float64(fmm_log_times), plotting = True, fig = final_fig, ax = final_axs[0,0], z_range = [-3.2,3.3], z_levels = 1000, x_range = [None, None], y_range = [None, None], cmap = 'jet', x_label = r"$\log_2{n}$", y_label ="p", z_label = r"$\log_{10}(\text{time / s})$", title = "FMM Simulation Time Varying n and p")
fmm_log_n_max_accuracy_result = util.analyse_2D([np.float64(item[0]) for item in fmm_log2_n_max_log_accuracy], [np.float64(item[1]) for item in fmm_log2_n_max_log_accuracy], np.float64(fmm_log_times), plotting = True, fig = final_fig, ax = final_axs[2,0], z_range = [-3.2, 3.2], z_levels = 1000, x_range = [None, None], y_range = [None, None], cmap = 'jet', x_label = r"$\log_2{n}$", y_label = r"$\log_{10}(\text{maximum error})$", z_label = r"$\log_{10}(\text{time / s})$", title = "FMM Simulation Time for Given N and Maximum Error")
fmm_log_n_mean_accuracy_result = util.analyse_2D([np.float64(item[0]) for item in fmm_log2_n_mean_log_accuracy], [np.float64(item[1]) for item in fmm_log2_n_mean_log_accuracy], np.float64(fmm_log_times), plotting = True, fig = final_fig, ax = final_axs[1,0], z_range = [-3.2, 3.2], z_levels = 1000, x_range = [None, None], y_range = [None, None], cmap = 'jet', x_label = r"$\log_2{n}$", y_label = r"$\log_{10}(\text{mean error})$", z_label = r"$\log_{10}(\text{time / s})$", title = "FMM Simulation Time for Given N and Mean Error")
fmm_log_n_p_accuracy_result = util.analyse_2D([np.float64(item[0]) for item in fmm_log2_n_p], [np.float64(item[1]) for item in fmm_log2_n_p], [np.float64(item[1]) for item in fmm_log2_n_max_log_accuracy], plotting = True, fig = final_fig, ax = final_axs[4,0], z_range = [None, 0], z_levels = 1000, x_range = [None, None], y_range = [None, None], cmap = 'jet', x_label = r"$\log_2{n}$", y_label = "p", z_label = r"$\log_{10}(\text{max error})$", title = "FMM Maximum Simulation Accuracy, Varying p and n")

fmm_fit_ns = 2**np.array(fmm_log2_n_p)[:,0]
fmm_fit_ps = np.array(fmm_log2_n_p)[:,1]
fmm_fit_times = 10**np.array(fmm_log_times)
fmm_p_x_data = np.vstack((fmm_fit_ns, fmm_fit_ps))
def fmm_complexity(X, a, b, d, e):
    n, y = X
    return n * (-2*a*y+56*b*(y**2)+4.5*d*np.sqrt(n)+e)

fmm_p_popt, fmm_p_pcov = curve_fit(fmm_complexity, fmm_p_x_data, fmm_fit_times)
expected_times = fmm_complexity(fmm_p_x_data, fmm_p_popt[0], fmm_p_popt[1], fmm_p_popt[2], fmm_p_popt[3])
fmm_fit_real_diff = util.analyse_2D(np.log2(fmm_fit_ns), fmm_fit_ps, np.log10(np.abs((fmm_fit_times-expected_times)/expected_times)), True, z_range=[-3,3], fig=final_fig, ax=final_axs[3,0], x_label=r"$log_2(n)$", y_label="p", z_label=r"$\log_{10}(\text{Relative Measured - Predicted Simulation Times / s})$", title=r"FMM (Measured - Predicted) Times; $a=$" + '{0:.1e}'.format(fmm_p_popt[0]) + r", b="+ '{0:.1e}'.format(fmm_p_popt[1]) + r", c="+ '{0:.1e}'.format(fmm_p_popt[2]) + r", d="+ '{0:.1e}'.format(fmm_p_popt[3]))



bh_log2_n_log10_theta = []
bh_log2_n_mean_log_accuracy = []
bh_log2_n_max_log_accuracy = []
bh_log_times = []
for i, n in enumerate(ns):
    for j, theta in enumerate(thetas):
        bh_log2_n_log10_theta.append([np.log2(n),np.log10(theta)])
        bh_log2_n_mean_log_accuracy.append([np.log2(n), log_bh_direct_diff_results[i][j].mean])
        bh_log2_n_max_log_accuracy.append([np.log2(n), log_bh_direct_diff_results[i][j].max])
        bh_log_times.append(np.log10(log_bh_direct_diff_results[i][j].sim_time))

bh_log_n_p_result = util.analyse_2D([np.float64(item[0]) for item in bh_log2_n_log10_theta], [np.float64(item[1]) for item in bh_log2_n_log10_theta], np.float64(bh_log_times), plotting = True, fig = final_fig, ax = final_axs[0,1], z_range = [-3.2,3.3], z_levels = 1000, x_range = [None, None], y_range = [None, None], cmap = 'jet', x_label = r"$\log_2{n}$", y_label =r"$\log_{10}(\theta)$", z_label = r"$\log_{10}(\text{time / s})$", title = r"BH Simulation Time Varying n and $\theta$")
bh_log_n_max_accuracy_result = util.analyse_2D([np.float64(item[0]) for item in bh_log2_n_max_log_accuracy], [np.float64(item[1]) for item in bh_log2_n_max_log_accuracy], np.float64(bh_log_times), plotting = True, fig = final_fig, ax = final_axs[2,1], z_range = [-3.2, 3.2], z_levels = 1000, x_range = [None, None], y_range = [None, None], cmap = 'jet', x_label = r"$\log_2{n}$", y_label = r"$\log_{10}(\text{maximum error})$", z_label = r"$\log_{10}(\text{time / s})$", title = "BH Simulation Time for Given N and Maximum Error")
bh_log_n_mean_accuracy_result = util.analyse_2D([np.float64(item[0]) for item in bh_log2_n_mean_log_accuracy], [np.float64(item[1]) for item in bh_log2_n_mean_log_accuracy], np.float64(bh_log_times), plotting = True, fig = final_fig, ax = final_axs[1,1], z_range = [-3.2, 3.2], z_levels = 1000, x_range = [None, None], y_range = [None, None], cmap = 'jet', x_label = r"$\log_2{n}$", y_label = r"$\log_{10}(\text{mean error})$", z_label = r"$\log_{10}(\text{time / s})$", title = "BH Simulation Time for Given N and Mean Error")



final_fig.set_size_inches(20,20)
final_fig.tight_layout()
